# %% [markdown]
# # Parcel matching (state=60)

# %%
import os
import numpy as np
from cneuromod_embeddings.dypac_utils import get_root_data, load_dypac
from cneuromod_embeddings.repro_summary import load_repro, visu_match

# %%
root_data = get_root_data('friends-s01_clean')
xp_type = 'friends-s01_clean'
fwhm = 5
cluster = 20
state = 60
R = load_repro(root_data=os.path.join(root_data, 'repro_friends-s01'), fwhm=fwhm, cluster=cluster, state=state)

# %% [markdown]
# ## Intra-subject matching

# %%
subject = 'sub-01'
Rintra = R[subject][subject]
match_val = np.max(Rintra, axis=0)
match_pair = np.argmax(Rintra, axis=0)
order = np.argsort(-match_val)
model1, mask_img1 = load_dypac(subject=subject, root_data=root_data, fwhm=fwhm, cluster=cluster, state=state, batch="even", xp_type=xp_type)
model2, mask_img2 = load_dypac(subject=subject, root_data=root_data, fwhm=fwhm, cluster=cluster, state=state, batch="odd", xp_type=xp_type)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-8394ef1f562f> in <module>
#       4 match_pair = np.argmax(Rintra, axis=0)
#       5 order = np.argsort(-match_val)
# ----> 6 model1, mask_img1 = load_dypac(subject=subject, root_data=root_data, fwhm=fwhm, cluster=cluster, state=state, batch="even", xp_type=xp_type)
#       7 model2, mask_img2 = load_dypac(subject=subject, root_data=root_data, fwhm=fwhm, cluster=cluster, state=state, batch="odd", xp_type=xp_type)
#
# ~/git/cneuromod_embeddings/cneuromod_embeddings/dypac_utils.py in load_dypac(subject, root_data, fwhm, cluster, state, batch, xp_type)
#      81     )
#      82     pickle_in = open(file_model, "rb")
# ---> 83     model, mask_img = load_model(pickle_in)
#      84     # in early iterations of the project, models were generated by dypac and included empty states
#      85     # the two next lines eliminates those states
#
# ~/git/cneuromod_embeddings/cneuromod_embeddings/dypac_utils.py in load_model(pickle_in)
#      59
#      60 def load_model(pickle_in):
# ---> 61     model = pk.load(pickle_in)
#      62     pickle_in.close()
#      63     mask_img = model.masker_.mask_img_
#
# ModuleNotFoundError: No module named 'dypac_masker'

# %% [markdown]
# ### High reproducibility parcels

# %%
visu_match(0, 5, model1, model2, order, match_pair, match_val)

# %% [markdown]
# ### Median reproducibility parcels

# %%
visu_match(30, 5, model1, model2, order, match_pair, match_val)

# %% [markdown]
# ### Low reproducibility parcels

# %%
visu_match(50, 5, model1, model2, order, match_pair, match_val)

# %% [markdown]
# ## Inter-subject matching

# %%
Rintra.shape
model1.components_.shape
# Out:
# (58, 126637)

# %%
sub1 = 'sub-01'
sub2 = 'sub-05'
Rintra = R[sub1][sub2]
match_val = np.max(Rintra, axis=1)
match_pair = np.argmax(Rintra, axis=1)
order = np.argsort(-match_val)
model1, mask_img1 = load_dypac(subject=sub1, root_data=root_data, fwhm=fwhm, cluster=cluster, state=state, batch="even")
model2, mask_img2 = load_dypac(subject=sub2, root_data=root_data, fwhm=fwhm, cluster=cluster, state=state, batch="even")

# %% [markdown]
# ### High reproducibility parcels

# %%
visu_match(0, 5, model1, model2, order, match_pair, match_val)

# %% [markdown]
# ### Median reproducibility parcels

# %%
visu_match(30, 5, model1, model2, order, match_pair, match_val)

# %% [markdown]
# ### Low reproducibility parcels

# %%
visu_match(50, 5, model1, model2, order, match_pair, match_val)
